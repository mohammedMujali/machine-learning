# %% [markdown]
# # ARTI308 - Logistic Regression Assignment
#
# ## Completed Version
#
# This notebook completes the logistic regression assignment using `advertising.csv`. The model predicts whether a user clicked on an advertisement.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# /home/oai/.config/matplotlib is not a writable directory
# Matplotlib created a temporary cache directory at /tmp/matplotlib-k95c4kri because there was an issue with the default path (/home/oai/.config/matplotlib); it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# ## Get the Data

# %%
ad_data = pd.read_csv('advertising.csv')
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  ...            Timestamp  Clicked on Ad
# 0                     68.95   35  ...  2016-03-27 00:53:11              0
# 1                     80.23   31  ...  2016-04-04 01:39:02              0
# 2                     69.47   26  ...  2016-03-13 20:35:42              0
# 3                     74.15   29  ...  2016-01-10 02:31:19              0
# 4                     68.37   35  ...  2016-06-03 03:36:18              0
#
# [5 rows x 10 columns]

# %% [markdown]
# **Check the head of ad_data**

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  ...            Timestamp  Clicked on Ad
# 0                     68.95   35  ...  2016-03-27 00:53:11              0
# 1                     80.23   31  ...  2016-04-04 01:39:02              0
# 2                     69.47   26  ...  2016-03-13 20:35:42              0
# 3                     74.15   29  ...  2016-01-10 02:31:19              0
# 4                     68.37   35  ...  2016-06-03 03:36:18              0
#
# [5 rows x 10 columns]

# %% [markdown]
# **Use info and describe() on ad_data**

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age  ...         Male  Clicked on Ad
# count               1000.000000  1000.000000  ...  1000.000000     1000.00000
# mean                  65.000200    36.009000  ...     0.481000        0.50000
# std                   15.853615     8.785562  ...     0.499889        0.50025
# min                   32.600000    19.000000  ...     0.000000        0.00000
# 25%                   51.360000    29.000000  ...     0.000000        0.00000
# 50%                   68.215000    35.000000  ...     0.000000        0.50000
# 75%                   78.547500    42.000000  ...     1.000000        1.00000
# max                   91.430000    61.000000  ...     1.000000        1.00000
#
# [8 rows x 6 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
ad_data['Age'].plot(kind='hist', bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# **Create a jointplot showing Area Income versus Age.**

# %%
plt.scatter(ad_data['Age'], ad_data['Area Income'])
plt.xlabel('Age')
plt.ylabel('Area Income')
plt.title('Area Income versus Age')
# Out:
# Text(0.5, 1.0, 'Area Income versus Age')

# %% [markdown]
# **Create a jointplot showing the kde distributions of Daily Time spent on site vs. Age.**

# %%
plt.hexbin(ad_data['Age'], ad_data['Daily Time Spent on Site'], gridsize=25)
plt.xlabel('Age')
plt.ylabel('Daily Time Spent on Site')
plt.title('Daily Time Spent on Site versus Age')
plt.colorbar(label='Count')

# %% [markdown]
# **Create a jointplot of 'Daily Time Spent on Site' vs. 'Daily Internet Usage'**

# %%
plt.scatter(ad_data['Daily Time Spent on Site'], ad_data['Daily Internet Usage'])
plt.xlabel('Daily Time Spent on Site')
plt.ylabel('Daily Internet Usage')
plt.title('Daily Time Spent on Site vs Daily Internet Usage')
# Out:
# Text(0.5, 1.0, 'Daily Time Spent on Site vs Daily Internet Usage')

# %% [markdown]
# **Finally, create a pairplot with the hue defined by the 'Clicked on Ad' column feature.**

# %%
pd.plotting.scatter_matrix(
    ad_data[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage']],
    figsize=(10, 10), diagonal='hist'
)
plt.suptitle('Pair Plot for Main Numeric Features', y=1.02)
# Out:
# Text(0.5, 1.02, 'Pair Plot for Main Numeric Features')

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# **Split the data into training set and testing set using train_test_split**

# %%
from sklearn.model_selection import train_test_split

X = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Male']]
y = ad_data['Clicked on Ad']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=101
)

# %%
X_train.head()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 290                     50.52   31     72270.88                171.62     0
# 167                     86.06   31     53767.12                219.72     1
# 486                     83.97   40     66291.67                158.42     1
# 683                     76.83   28     67990.84                192.81     0
# 876                     67.39   44     51257.26                107.19     0

# %%
y_train.head()
# Out:
# 290    1
# 167    0
# 486    0
# 683    0
# 876    1
# Name: Clicked on Ad, dtype: int64

# %% [markdown]
# **Train and fit a logistic regression model on the training set.**

# %%
from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression(max_iter=1000)
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
logmodel.coef_
# Out:
# array([[-1.77418940e-01,  1.41046477e-01, -1.23155840e-04,
#         -5.99162561e-02, -4.65822878e-01]])

# %% [markdown]
# ## Predictions and Evaluations

# %%
predictions = logmodel.predict(X_test)
predictions[:10]
# Out:
# array([1, 0, 0, 1, 0, 1, 1, 1, 1, 1])

# %% [markdown]
# **Create a classification report for the model.**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test, predictions))
print('\nAccuracy:', accuracy_score(y_test, predictions))
print('\nClassification Report:')
print(classification_report(y_test, predictions))
# Out:
# [[155   2]
#  [  5 138]]
#
# Accuracy: 0.9766666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       157
#            1       0.99      0.97      0.98       143
#
#     accuracy                           0.98       300
#    macro avg       0.98      0.98      0.98       300
# weighted avg       0.98      0.98      0.98       300

# %% [markdown]
# ## Conclusion
#
# The assignment is now completed with working code, training/testing split, model fitting, predictions, and evaluation.
